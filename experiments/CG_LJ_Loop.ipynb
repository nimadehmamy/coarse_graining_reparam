# %%
# %matplotlib inline
# plot the molecule in 3D in an interactive window
# %matplotlib widget
# %config InlineBackend.figure_format = 'retina'

# %%
# get current working directory
import os, sys
pwd = os.getcwd()
# append ../src/ to the sys path to access the coarsegrainer package
sys.path.append(pwd + '/../src/')

# %%
pwd
# Out:
# '/home/nima/__work/Coarse_graining/coarse_graining_code_2024_02/experiments'

# %%
import time
# import collections

import numpy as np
import pandas as pd

import torch
# import torch.nn.functional as F

import matplotlib.pyplot as plt

### import the coarse-graining module
import coarsegrainer as cg
# from coarsegrainer.minimizer import EnergyMinimizerPytorch, CGMinimizerPytorch, GNNMinimizerPytorch
# from coarsegrainer.experimental.minimizer import EnergyMinimizerPytorch, CGMinimizerPytorch, GNNMinimizerPytorch
# from coarsegrainer.experimental.minimizer import EnergyMinimizer, CGMinimizer, GNNMinimizer
from coarsegrainer.minimizer import EnergyMinimizer, CGMinimizer, GNNMinimizer
from coarsegrainer.energy import Energy, LJ_potential, quadratic_potential 
from coarsegrainer.plotting import plot_line_3D, plot_graph

from experimentlogger import ExperimentLogger

V = lambda x: x.detach().cpu().numpy()

# %% [markdown]
# ## Quadratic Bonds + LJ loop
# Define an energy function which uses a quadratic potential for bonds and LJ for forming a loop.
# It consists of:
# 1. a strong backbone line graph LJ, where every node is attracted to the next
# 2. a weaker loop LJ, where every l-th pair of nodes are attracted

# %%
num_nodes, dims = 400, 3

n,d = num_nodes, dims
loop = 10
a = 1e-1

# init_sigma = 3.0 # initial standard deviation of the coordinates
# an initial std of 
init_sigma = n**(1/3)/2

device = 'cuda' if torch.cuda.is_available() else 'cpu'

A = cg.utils.line_graph_A(n, k=1).to(device)
vdw = cg.utils.line_graph_A(n, k=loop).to(device)

A_loop = A+a*vdw

x = init_sigma*torch.randn(n, d).to(device) 

plt.imshow(V(A-vdw)[:50,:50], cmap='seismic', vmin=-1, vmax=1)

# %%
energy_params = dict(radius = 1, thres_A = 1e-4, lj_pow = 6, repel_pow = 1, repel_mag = 2.5e-3, 
                device = 'cuda')

energy_lj = Energy([A_loop], [LJ_potential],log_name='Energy_LJ_2scale', **energy_params)
energy_bond_lj = Energy([A, .1*vdw], [quadratic_potential, LJ_potential],log_name='Energy_Bond_LJ', **energy_params)

# %%
energy_bond_lj(x).item(), 
energy_lj(x).item()
# Out:
# 0.030571801587939262

# %% [markdown]
# ## Training

# %%
# early stopping criteria
PATIENCE = 20
MIN_DELTA = 1e-6

# learning rate
LR = 2e-2

# %%
# exp_logger = ExperimentLogger(previous_results_csv='../results/CG_experiment_2024-02-09-01.csv')
exp_logger = ExperimentLogger(save_prefix='../results/CG_Bond_LJ_experiment') 
test_logger = ExperimentLogger(save_prefix='../results/test')

# %%
# df = exp_logger.df

# import seaborn as sns
# # plot the filtered dataframe using sns directly on df
# sns.relplot(data=df, x='time', y='energy', hue='model_name', style='model_name', kind='scatter', size='min_delta', height=6, aspect=1.7)

# # plt.ylim(-.0247, -.0238)
# # plt.xlim(7,30)
# plt.xscale('log')
# plt.grid()

# %% [markdown]
# ## LJ only

# %%
# example of using the EnergyMinimizerPytorch class
# define the initial position
# initial_pos = x = init_sigma*1*torch.randn(n, d).to(device) /2

initial_pos = x = init_sigma*torch.randn(n, d).to(device) /3
# instantiate the EnergyMinimizerPytorch class
# energy_minimizer = EnergyMinimizerPytorch(energy_lj, initial_pos, optimizer_type='Adam', lr=1e-2, clamp_grads=.1, log_step=20, log_pos_step=0, 
#                             log_dir='../results/logs', log_name='LJ_loop', patience=PATIENCE*1, min_delta=MIN_DELTA*1e-0)
energy_minimizer = EnergyMinimizer(energy_lj, initial_pos, optimizer_type='Adam', lr=1e-3, clamp_grads=.01, log_step=20, log_pos_step=0, 
                            log_dir='../results/logs', log_name='LJ_loop', patience=PATIENCE*1, min_delta=MIN_DELTA*1e-0)
# Out:
# Using Adam optimizer
# Log name: LJ_loop
# Logging to: ../results/logs/LJ_loop_n400_d3

# %%
energy_minimizer.logger

# %%
exp_logger.run_experiment(energy_minimizer, epochs=10, steps=5000, x0_std=initial_pos.std().item())
# Out:
# Running experiment LJ_loop_n400_d3
# 250 0.454, 3.76
# 500 0.45, 7.31
# 750 0.449, 10.89
# 1000 0.449, 14.43
# 1250 0.448, 17.96
# 1500 0.448, 21.73
# 1750 0.448, 25.49
# 2000 0.448, 29.12
# 2250 0.448, 32.66
# Early stopping at step 4320
# 2467 0.448, 35.69

# %%
energy_minimizer.plot_history(start=100)
h = energy_minimizer.history
plt.title(f'Energy vs time (min E: {min(h["energy"]):.3g}, t={np.sum(h["time"]):.2f} s)')
# Out:
# Text(0.5, 1.0, 'Energy vs time (min E: 0.3, t=35.42 s)')

# %%
exp_logger.df
# Out:
#     energy_function       model_name    energy       time     lr  clamp_grads  \
# 0  Energy_LJ_2scale  LJ_loop_n400_d3  0.299706  35.420809  0.001         0.01
#
#    patience  min_delta    x0_std
# 0        20   0.000001  1.238324

# %%
energy_minimizer.get_x().std(), init_sigma
# Out:
# (tensor(5.1249, device='cuda:0', grad_fn=<StdBackward0>), 3.6840314986403864)

# %%
r = 2.5e-1
# v = plot_graph_3D(V(energy_minimizer.get_x()), A,  node_radius=r/2, edge_thickness=r, eps=1e-4, node_color='blue', edge_color='blue')
v = plot_line_3D(V(energy_minimizer.get_x()), A, r = r, eps=1e-4, colormap='jet')
# Capture the current view as a PNG image
# v.png()
# Out:
# <div id="3dmolviewer_17150229663326411"  style="position: relative; width: 600px; height: 600px;">
#         <p id="3dmolwarning_17150229663326411" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17150229663326411 = null;
# var warn = document.getElementById("3dmolwarning_17150229663326411");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17150229663326411 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17150229663326411"),{backgroundColor:"white"});
# viewer_17150229663326411.zoomTo();
# 	viewer_17150229663326411.addCylinder({"start": {"x": 0.776914119720459, "y": -0.5569562911987305, "z": 9.233111381530762}, "end": {"x": 1.2947962284088135, "y": -1.408703327178955, "z": 8.696239471435547}, "radius": 0.125, "color": "#000080", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x
"opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": 0.9398408532142639, "y": -1.6143678426742554, "z": 7.244584560394287}, "end": {"x": 0.12122401595115662, "y": -1.049915075302124, "z": 7.786369323730469}, "radius": 0.125, "color": "#0000ad", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": 0.12122401595115662, "y": -1.049915075302124, "z": 7.786369323730469}, "end": {"x": -0.8756981492042542, "y": -0.5842100977897644, "z": 8.052291870117188}, "radius": 0.125, "color": "#0000b2", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": -0.8756981492042542, "y": -0.5842100977897644, "z": 8.052291870117188}, "end": {"x": -0.631225049495697, "y": -1.6765003204345703, "z": 7.883143424987793}, "radius": 0.125, "color": "#0000b6", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": -0.631225049495697, "y": -1.6765003204345703, "z": 7.883143424987793}, "end": {"x": -0.19502487778663635, "y": -2.6982805728912354, "z": 7.664228439331055}, "radius": 0.125, "color": "#0000b6", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": -0.19502487778663635, "y": -2.6982805728912354, "z": 7.664228439331055}, "end": {"x": 0.8516945242881775, "y": -2.9889461994171143, "z": 7.345846652984619}, "radius": 0.125, "color": "#0000bb", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": 0.8516945242881775, "y": -2.9889461994171143, "z": 7.345846652984619}, "end": {"x": 0.986994206905365, "y": -3.839451551437378, "z": 6.610607624053955}, "radius": 0.125, "color": "#0000bf", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": 0.986994206905365, "y": -3.839451551437378, "z": 6.610607624053955}, "end": {"x": 1.809401035308838, "y": -4.2675604820251465, "z": 5.961190223693848}, "radius": 0.125, "color": "#0000bf", "opacity": 1});
# 	viewer_17150229663326411.addCylinder({"start": {"x": 1.809401035308838, "y": -4.2675604820251465

# %%
# exp_logger = ExperimentLogger(previous_results_csv='../results/CG_experiment_2024-02-09-01.csv')
exp_logger = ExperimentLogger(save_prefix='../results/CG_Bond_LJ_experiment') 
test_logger = ExperimentLogger(save_prefix='../results/test')

# %%
h = energy_minimizer.train(5000)
# Out:
# Early stopping at step 4080

# %%
exp_logger.df
# Out:
#     energy_function       model_name    energy       time     lr  clamp_grads  \
# 0  Energy_LJ_2scale  LJ_loop_n400_d3 -0.006895  35.318704  0.001         0.01
#
#    patience  min_delta    x0_std
# 0        20   0.000001  1.292495

# %%
energy_minimizer.get_x().std(), init_sigma
# Out:
# (tensor(5.5694, device='cuda:0', grad_fn=<StdBackward0>), 3.6840314986403864)

# %% [markdown]
# ### CG Using multiple samples

# %%
init_sigma
# Out:
# 3.6840314986403864

# %%
t0 = time.time()
# x_samples = init_sigma/2*torch.randn(4*n, n, d, device =device)
# note: large init_sigma resulted in diverging hessian
# x_samples = init_sigma*1*torch.randn(4*n, n, d, device =device)
k = 40
# produce k samples with different std for x
x_samples = init_sigma*torch.randn(k, n, d, device =device)*torch.linspace(1e-2, 2e-1, k)[:, None, None].to(device)
# x_samples = init_sigma*torch.randn(k, n, d, device =device)*torch.linspace(1e-1, 2e-0, k)[:, None, None].to(device)
cg_bond_lj = cg.CG.CoarseGrainer(energy_lj, num_cg_modes=120)
cg_bond_lj.get_cg_modes(x_samples)
cg_time = time.time() - t0
print(f'CG time {cg_time:.3g}')
# Out:
# force constant matrix computed in 0.43 seconds
# spectrum of the Laplacian computed in 0.03 seconds
# CG time 0.483

# %%
init_sigma/16, 1/(2*d)
# Out:
# (0.23025196866502415, 0.16666666666666666)

# %%
A.shape, x.shape
# Out:
# (torch.Size([400, 400]), torch.Size([400, 3]))

# %%
b = 1e-3
plt.imshow(np.arcsinh(1e3*V(cg_bond_lj.L)), cmap='seismic', vmin=-b, vmax=b)

# %%
c = V(cg_bond_lj.cg_modes)
plt.imshow(c, cmap='seismic', vmin=-1, vmax=1)

# %%
# cg_minimizer.start_fine_graining()
# cg_minimizer.early_stopping_triggered = False
# h = cg_minimizer.train(20000)

# %% [markdown]
# ### Multi-stage CG
# gradually increase the number cg modes used

# %%
cg_min_params = dict(optimizer_type='Adam', lr=LR, lr_cg=1e-1,
            clamp_grads=.01, log_step=20, log_pos_step=0, 
            log_dir='../results/logs', log_name='CG_LJ_loop', 
            patience=PATIENCE, min_delta=MIN_DELTA*1e-2,
            cg_patience=PATIENCE, cg_min_delta=MIN_DELTA*1e-2)

# %%
num_cg_modes = n//4
initial_pos = x = init_sigma*torch.randn(n, d).to(device)/4 # 3
# instantiate the CGMinimizerPytorch class
cg_minimizer = CGMinimizer(energy_lj, initial_pos, cg_bond_lj.cg_modes[:,:num_cg_modes], **cg_min_params)
# Out:
# Using Adam optimizer
# Log name: CG_LJ_loop
# Logging to: ../results/logs/CG_LJ_loop_n400_d3
# Using Adam optimizer

# %%
initial_pos.std()
# Out:
# tensor(0.9007, device='cuda:0')

# %%
exp_logger.run_experiment(cg_minimizer, epochs=10, steps=5000, x0_std=initial_pos.std().item())
# Out:
# Running experiment CG_LJ_loop_n400_d3
# 250 0.125, 3.97
# 500 0.123, 7.81
# Early stopping at step 3140
# Starting fine-graining
# 908 0.0877, 13.90
# 1158 0.087, 17.56
# 1408 0.0866, 21.21
# Early stopping at step 4020
# 1610 0.0858, 24.16

# %%
for i in range(10):
    h= cg_minimizer.train(20000)
# Out:
# Early stopping at step 4880
# Early stopping at step 4220
# Early stopping at step 2960
# Early stopping at step 1800
# Early stopping at step 1300
# Early stopping at step 2880
# Early stopping at step 5940
# Early stopping at step 2040
# Early stopping at step 4580
# Early stopping at step 2400

# %%
cg_minimizer.cg_steps
# Out:
# 658

# %%
cg_minimizer.plot_history(start=100)
cg_minimizer.plot_history(start=cg_minimizer.cg_steps+0)
h = cg_minimizer.history
plt.title(f'Energy vs time (min E: {min(h["energy"]):.3g}, t={np.sum(h["time"]):.2f} s)')
# Out:
# Text(0.5, 1.0, 'Energy vs time (min E: 0.0845, t=48.49 s)')

# %%
cg_minimizer.fine_grained
# Out:
# True

# %%
r = 5e-1
# v = plot_graph_3D(V(cg_minimizer.get_x()), A, node_radius=r/2, edge_thickness=r, eps=1e-4, node_color='red', edge_color='red')
v = plot_line_3D(V(cg_minimizer.get_x()), A, r = 5e-1, eps=1e-4, colormap='jet')

# Capture the current view as a PNG image
# v.png()
# Out:
# <div id="3dmolviewer_17150231075608432"  style="position: relative; width: 600px; height: 600px;">
#         <p id="3dmolwarning_17150231075608432" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0
"opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -22.273569107055664, "y": 0.4026431441307068, "z": 10.389074325561523}, "end": {"x": -21.417516708374023, "y": 1.1243584156036377, "z": 10.5512056350708}, "radius": 0.25, "color": "#0000a4", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -21.417516708374023, "y": 1.1243584156036377, "z": 10.5512056350708}, "end": {"x": -20.3475284576416, "y": 1.2633408308029175, "z": 10.207494735717773}, "radius": 0.25, "color": "#0000a8", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -20.3475284576416, "y": 1.2633408308029175, "z": 10.207494735717773}, "end": {"x": -19.220823287963867, "y": 1.1507675647735596, "z": 10.18502426147461}, "radius": 0.25, "color": "#0000ad", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -19.220823287963867, "y": 1.1507675647735596, "z": 10.18502426147461}, "end": {"x": -19.10787010192871, "y": 0.6262354254722595, "z": 9.19008731842041}, "radius": 0.25, "color": "#0000ad", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -19.10787010192871, "y": 0.6262354254722595, "z": 9.19008731842041}, "end": {"x": -19.40988540649414, "y": -0.33413174748420715, "z": 8.667112350463867}, "radius": 0.25, "color": "#0000b2", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -19.40988540649414, "y": -0.33413174748420715, "z": 8.667112350463867}, "end": {"x": -20.382633209228516, "y": -0.8850073218345642, "z": 8.501221656799316}, "radius": 0.25, "color": "#0000b6", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -20.382633209228516, "y": -0.8850073218345642, "z": 8.501221656799316}, "end": {"x": -21.402389526367188, "y": -1.0718153715133667, "z": 8.962196350097656}, "radius": 0.25, "color": "#0000b6", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -21.402389526367188, "y": -1.0718153715133667, "z": 8.962196350097656}, "end": {"x": -22.170244216918945, "y": -0.7917570471763611, "z": 9.742093086242676}, "radius": 0.25, "color": "#0000bb", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -22.170244216918945, "y": -0.7917570471763611, "z": 9.742093086242676}, "end": {"x": -22.51150894165039, "y": -0.5154388546943665, "z": 10.787809371948242}, "radius": 0.25, "color": "#0000bf", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -22.51150894165039, "y": -0.5154388546943665, "z": 10.787809371948242}, "end": {"x": -22.05594253540039, "y": 0.24459615349769592, "z": 11.487519264221191}, "radius": 0.25, "color": "#0000bf", "opacity": 1});
# 	viewer_17150231075608432.addCylinder({"start": {"x": -22.05594253540039, "y": 0.24459615349

# %%
# h = cg_minimizer.train_one_stage(20000)

# %%
cg_minimizer.history.keys()
# Out:
# dict_keys(['time', 'energy', 'x'])

# %%
t0 = time.time()
# x_samples = init_sigma/2*torch.randn(4*n, n, d, device =device)
# note: large init_sigma resulted in diverging hessian
# x_samples = init_sigma*1*torch.randn(4*n, n, d, device =device)
k = 10
# produce k samples with different std for x

x0 = cg_minimizer.get_x().detach().clone()
s = x0.std().item()

x_samples = s/10*torch.randn(k, n, d, device = device)*torch.linspace(2e-1, 1e0, k)[:, None, None].to(device)
x_samples = x_samples + x0

cg_bond_lj = cg.CG.CoarseGrainer(energy_lj, num_cg_modes=120)
cg_bond_lj.get_cg_modes(x_samples)
cg_time = time.time() - t0
cg_time
# Out:
# force constant matrix computed in 0.07 seconds
# spectrum of the Laplacian computed in 0.01 seconds
# 0.08427906036376953

# %%
b = 1e-3
plt.imshow(np.arcsinh(1e3*V(cg_bond_lj.L)), cmap='seismic', vmin=-b, vmax=b)

# %%
c = V(cg_bond_lj.cg_modes)
plt.imshow(c, cmap='seismic', vmin=-1, vmax=1)

# %%
x.std()
# Out:
# tensor(0.9358, device='cuda:0')

# %% [markdown]
# ## GNN

# %%
from coarsegrainer.GNN import GNNReparam
# example of using the GNNMinimizerPytorch class
# define the initial position
initial_pos = x = init_sigma*torch.randn(n, d).to(device)/4
print(f"Initial std of x: {x.std().item():.3g}")

# example of using the GNNReparam class
h=20
num_cg_modes = n//3

n = len(A)
# similar to xavier initialization, we can set latent_sigma to 1/sqrt(h)
gnn_reparam = GNNReparam([h, h//2, d], cg=cg_bond_lj, num_cg=num_cg_modes, # latent_sigma=1/np.sqrt(h), 
                        bias=True, activation=torch.nn.Tanh(), output_init_sigma= x.std().item(), 
                        device=device,
                        )#.to(device)
# print(f"std before rescaling {gnn_reparam().std().item():.3g}")
# gnn_reparam.rescale_output(x.std().item())

# since std of x is init_sigma, std of gnn_reparam should be init_sigma
# but because of the gnn, it is not
# we can use the last linear layer to scale the output to match x
# we can use the std of the last layer to scale the output
# we will rescale the parameters of the last layer to match the std of x

# init_gnn_std = gnn_reparam().std()
# # rescale the weights of the last layer by the ratio of the stds
# # gnn_reparam.gnn.layers[-1].weight.data *= init_sigma/init_gnn_std*1.

# gnn_reparam.gnn.layers[-1].weight.data *= x.std().item()/init_gnn_std*1.
print(f"std after rescaling {gnn_reparam().std().item():.3g}")

# instantiate the GNNMinimizerPytorch class
# gnn_minimizer = GNNMinimizerPytorch(
gnn_minimizer = GNNMinimizer(
    energy_lj, 1*initial_pos, gnn_reparam, optimizer_type='Adam', 
                            lr=1*LR, lr_gnn=2e-3,
                            # lr=2*LR, lr_gnn=4e-3,
                            clamp_grads=1e-2, log_step=20, log_pos_step=0, 
                            log_dir='../results/logs', log_name=f'GNN_Bond_LJ{num_cg_modes/n:.2f}',
                            patience=PATIENCE, min_delta=MIN_DELTA*1e-1, 
                            gnn_patience=PATIENCE, gnn_min_delta=MIN_DELTA*1e-1)
# Out:
# Initial std of x: 0.916
# std after rescaling 0.875
# Using Adam optimizer
# Log name: GNN_Bond_LJ0.33
# Logging to: ../results/logs/GNN_Bond_LJ0.33_n400_d3
# Using Adam optimizer

# %%
gnn_minimizer.energy_func(x), gnn_minimizer.energy_func(gnn_minimizer.get_x())
# Out:
# (tensor(1.8615, device='cuda:0'),
#  tensor(2.0104, device='cuda:0', grad_fn=<AddBackward0>))

# %%
# gnn_minimizer.min_delta *= 1e-1

# %%
# for i in range(20):
#     gnn_minimizer.early_stop.reset()
#     h= super(GNNMinimizer, gnn_minimizer).train(20000, update_pairs=True)

# %%
exp_logger.run_experiment(gnn_minimizer, epochs=10, steps=5000, x0_std=initial_pos.std().item())
# Out:
# Running experiment GNN_Bond_LJ0.33_n400_d3
# 250 0.346, 5.23
# 500 0.346, 10.22
# Early stopping at step 3260
# Starting fine-graining
# 914 0.346, 17.12
# 1164 0.346, 20.78
# 1414 0.346, 24.42
# Early stopping at step 2060
# 1518 0.346, 25.91

# %%
for i in range(10):
    h= gnn_minimizer.train(20000)
# Out:
# Early stopping at step 4840
# Early stopping at step 3060
# Early stopping at step 3780
# Early stopping at step 2620
# Early stopping at step 1880
# Early stopping at step 2000
# Early stopping at step 1200
# Early stopping at step 1080
# Early stopping at step 1400
# Early stopping at step 1000

# %%
gnn_minimizer.early_stop.min_delta
# Out:
# 1e-07

# %%
gnn_minimizer.plot_history(start=100)
gnn_minimizer.plot_history(start=gnn_minimizer.gnn_steps)
h = gnn_minimizer.history
plt.title(f'Energy vs time (min E: {min(h["energy"]):.3g}, t={np.sum(h["time"]):.2f} s)')
# Out:
# Text(0.5, 1.0, 'Energy vs time (min E: 0.346, t=25.91 s)')

# %%
r = 3e-1
# v = plot_graph_3D(V(cg_minimizer.get_x()), A, node_radius=r/2, edge_thickness=r, eps=1e-4, node_color='red', edge_color='red')
v = plot_line_3D(V(gnn_minimizer.get_x()), A, r = r, eps=1e-4, colormap='jet')

# Capture the current view as a PNG image
# v.png()
# Out:
# <div id="3dmolviewer_17150265842918272"  style="position: relative; width: 600px; height: 600px;">
#         <p id="3dmolwarning_17150265842918272" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17150265842918272 = null;
# var warn = document.getElementById("3dmolwarning_17150265842918272");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17150265842918272 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17150265842918272"),{backgroundColor:"white"});
# viewer_17150265842918272.zoomTo();
# 	viewer_17150265842918272.addCylinder({"start": {"x": 7.92516565322876, "y": 6.56856632232666, "z": -4.762307167053223}, "end": {"x": 7.4294915199279785, "y": 5.556306838989258, "z": -4.90994930267334}, "radius": 0.15, "color": "#000080", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 7.4294915199279785, "y": 5.556306838989258, "z": -4.90994930267334}, "end": {"x": 6.484063148498535, "y": 5.943078994750977, "z": -4.426934242248535}, "radius": 0.15, "color": "#000080", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 6.484063148498535, "y": 5.943078994750977, "z": -4.426934242248535}, "end": {"x": 6.930739879608154, "y": 6.01055383682251, "z": -3.388483762741089}, "radius": 0.15, "color": "#000084", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 6.930739879608154, "y": 6.01055383682251, "z": -3.388483762741089}, "end": {"x": 7.0502705574035645, "y": 5.840487480163574, "z": -2.275761604309082}, "radius": 0.15, "color": "#000084", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 7.0502705574035645, "y": 5.840487480163574, "z": -2.275761604309082}, "end": {"x": 7.731674671173096, "y": 5.9409027099609375, "z": -1.3769400119781494}, "radius": 0.15, "color": "#000089", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 7.731674671173096, "y": 5.9409027099609375, "z": -1.3769400119781494}, "end": {"x": 8.40927505493164, "y": 5.3483076095581055, "z": -0.6905984282493591}, "radius": 0.15, "color": "#00008d", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 8.40927505493164, "y": 5.3483076095581055, "z": -0.6905984282493591}, "end": {"x": 9.092460632324219, "y": 5.140638828277588, "z": -1.5676753520965576}, "radius": 0.15, "color": "#00008d", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 9.092460632324219, "y": 5.140638828277588, "z": -1.5676753520965576}, "end": {"x": 8.617916107177734, "y": 6.001907825469971, "z": -2.1336867809295654}, "radius": 0.15, "color": "#000092", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x":
"opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 5.336114406585693, "y": 4.7934699058532715, "z": -3.1510982513427734}, "end": {"x": 5.302712917327881, "y": 4.600024700164795, "z": -2.0380609035491943}, "radius": 0.15, "color": "#0000bf", "opacity": 1});
# 	viewer_17150265842918272.addCylinder({"start": {"x": 5.302712917327881, "y": 4.600024700164795, "z": -2.0380609035491943}, "end": {"x": 6.023164749145508, "y": 4.6895742

# %% [markdown]
# ### Using Adj matrix

# %%
plt.imshow(V(A_loop)[:20,:20], cmap='seismic', vmin=-1, vmax=1)

# %%
# from coarsegrainer.GNN import GNNReparam
# example of using the GNNMinimizerPytorch class
# define the initial position
initial_pos = x = init_sigma*torch.randn(n, d).to(device)/4
print(f"Initial std of x: {x.std().item():.3g}")

# example of using the GNNReparam class
h=20
num_cg_modes = n//3

n = len(A)
# similar to xavier initialization, we can set latent_sigma to 1/sqrt(h)
gnn_reparam = GNNReparam([h, h//2, d], A=A_loop, # latent_sigma=1/np.sqrt(h), 
                        bias=True, activation=torch.nn.Tanh(), output_init_sigma= x.std().item(), 
                        device=device,
                        )#.to(device)
# print(f"std before rescaling {gnn_reparam().std().item():.3g}")
# gnn_reparam.rescale_output(x.std().item())

# since std of x is init_sigma, std of gnn_reparam should be init_sigma
# but because of the gnn, it is not
# we can use the last linear layer to scale the output to match x
# we can use the std of the last layer to scale the output
# we will rescale the parameters of the last layer to match the std of x

# init_gnn_std = gnn_reparam().std()
# # rescale the weights of the last layer by the ratio of the stds
# # gnn_reparam.gnn.layers[-1].weight.data *= init_sigma/init_gnn_std*1.

# gnn_reparam.gnn.layers[-1].weight.data *= x.std().item()/init_gnn_std*1.
print(f"std after rescaling {gnn_reparam().std().item():.3g}")

# instantiate the GNNMinimizerPytorch class
# gnn_minimizer = GNNMinimizerPytorch(
gnn_minimizer = GNNMinimizer(
    energy_lj, 1*initial_pos, gnn_reparam, optimizer_type='Adam', 
                            lr=1*LR, lr_gnn=2e-3,
                            # lr=2*LR, lr_gnn=4e-3,
                            clamp_grads=1e-2, log_step=20, log_pos_step=0, 
                            log_dir='../results/logs', log_name=f'GNN_Bond_LJ{num_cg_modes/n:.2f}',
                            patience=PATIENCE, min_delta=MIN_DELTA*1e-1, 
                            gnn_patience=PATIENCE, gnn_min_delta=MIN_DELTA*1e-1)
# Out:
# Initial std of x: 0.93
# std after rescaling 0.782
# Using Adam optimizer
# Log name: GNN_Bond_LJ0.33
# Logging to: ../results/logs/GNN_Bond_LJ0.33_n400_d3
# Using Adam optimizer

# %%
gnn_minimizer.energy_func(x), gnn_minimizer.energy_func(gnn_minimizer.get_x())
# Out:
# (tensor(1.4936, device='cuda:0'),
#  tensor(4.6941, device='cuda:0', grad_fn=<AddBackward0>))

# %%
exp_logger.run_experiment(gnn_minimizer, epochs=10, steps=5000, x0_std=initial_pos.std().item())
# Out:
# Running experiment GNN_Bond_LJ0.33_n400_d3
# 250 1.42, 5.09
# 500 1.42, 10.04
# 750 1.42, 14.98
# Early stopping at step 4260
# Starting fine-graining
# Early stopping at step 3260
# 1128 1.42, 21.60

# %%
# for i in range(10):
#     h= gnn_minimizer.train(20000)

# %%
gnn_minimizer.plot_history(start=100)
gnn_minimizer.plot_history(start=gnn_minimizer.gnn_steps)
h = gnn_minimizer.history
plt.title(f'Energy vs time (min E: {min(h["energy"]):.3g}, t={np.sum(h["time"]):.2f} s)')
# Out:
# Text(0.5, 1.0, 'Energy vs time (min E: 1.42, t=21.60 s)')

# %%
r = 3e-1
# v = plot_graph_3D(V(cg_minimizer.get_x()), A, node_radius=r/2, edge_thickness=r, eps=1e-4, node_color='red', edge_color='red')
v = plot_line_3D(V(gnn_minimizer.get_x()), A, r = r, eps=1e-4, colormap='jet')

# Capture the current view as a PNG image
# v.png()
# Out:
# <div id="3dmolviewer_17150266371009545"  style="position: relative; width: 600px; height: 600px;">
#         <p id="3dmolwarning_17150266371009545" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_17150266371009545 = null;
# var warn = document.getElementById("3dmolwarning_17150266371009545");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_17150266371009545 = $3Dmol.createViewer(document.getElementById("3dmolviewer_17150266371009545"),{backgroundColor:"white"});
# viewer_17150266371009545.zoomTo();
# 	viewer_17150266371009545.addCylinder({"start": {"x": 5.004123210906982, "y": -1.6136335134506226, "z": 6.794332027435303}, "end": {"x": 4.14384126663208, "y": -2.31626296043396, "z": 6.579531669616699}, "radius": 0.15, "color": "#000080", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 4.14384126663208, "y": -2.31626296043396, "z": 6.579531669616699}, "end": {"x": 3.5849337577819824, "y": -3.0796985626220703, "z": 5.956014156341553}, "radius": 0.15, "color": "#000080", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 3.5849337577819824, "y": -3.0796985626220703, "z": 5.956014156341553}, "end": {"x": 3.7947921752929688, "y": -3.3918278217315674, "z": 4.8887224197387695}, "radius": 0.15, "color": "#000084", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 3.7947921752929688, "y": -3.3918278217315674, "z": 4.8887224197387695}, "end": {"x": 4.783050537109375, "y": -3.012127161026001, "z": 4.4851531982421875}, "radius": 0.15, "color": "#000084", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 4.783050537109375, "y": -3.012127161026001, "z": 4.4851531982421875}, "end": {"x": 5.687594413757324, "y": -2.3673722743988037, "z": 4.269522190093994}, "radius": 0.15, "color": "#000089", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 5.687594413757324, "y": -2.3673722743988037, "z": 4.269522190093994}, "end": {"x": 6.262886047363281, "y": -1.40837562084198, "z": 4.447091102600098}, "radius": 0.15, "color": "#00008d", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 6.262886047363281, "y": -1.40837562084198, "z": 4.447091102600098}, "end": {"x": 6.7211785316467285, "y": -0.5111424326896667, "z": 4.9640069007873535}, "radius": 0.15, "color": "#00008d", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 6.7211785316467285, "y": -0.5111424326896667, "z": 4.9640069007873535}, "end": {"x": 6.286256313323975, "y": 0.31379812955856323, "z": 5.602340221405029}, "radius": 0.15, "color": "#000092", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 6.286256313323975, "y": 0.31379812955856323, "z": 5.602340221405029}, "end": {"x": 5.787940502166748, "y": 0.4521620571613312, "z": 6.6118059158325195}, "radius": 0.15, "color": "#000096", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x": 5.787940502166748, "y": 0.4521620571613312, "z": 6.6118059158325195}, "end": {"x": 5.376749515533447, "y": -0.5935196280479431, "z": 6.473263263702393}, "radius": 0.15, "color": "#000096", "opacity": 1});
# 	viewer_17150266371009545.addCylinder({"start": {"x":
edgelist
# Out:
# tensor([[0.0000e+00, 1.0000e+00, 1.0000e+00],
#         [0.0000e+00, 1.0000e+01, 1.0000e-01],
#         [1.0000e+00, 0.0000e+00, 1.0000e+00],
#         ...,
#         [3.9800e+02, 3.9900e+02, 1.0000e+00],
#         [3.9900e+02, 3.8900e+02, 1.0000e-01],
#         [3.9900e+02, 3.9800e+02, 1.0000e+00]], device='cuda:0')

# %%
edgelist.shape
# Out:
# torch.Size([1578, 3])

# %%
from coarsegrainer.GNN import GNNReparam
# example of using the GNNMinimizerPytorch class
# define the initial position
initial_pos = x = init_sigma*torch.randn(n, d).to(device)/4
print(f"Initial std of x: {x.std().item():.3g}")

# example of using the GNNReparam class
h=20
num_cg_modes = n//3

n = len(A)
# similar to xavier initialization, we can set latent_sigma to 1/sqrt(h)
gnn_reparam = GNNReparam([h, h//2, d], edgelist=edgelist, # latent_sigma=1/np.sqrt(h), 
                        bias=True, activation=torch.nn.Tanh(), output_init_sigma= x.std().item(), 
                        device=device,
                        )#.to(device)
# print(f"std before rescaling {gnn_reparam().std().item():.3g}")
# gnn_reparam.rescale_output(x.std().item())

# since std of x is init_sigma, std of gnn_reparam should be init_sigma
# but because of the gnn, it is not
# we can use the last linear layer to scale the output to match x
# we can use the std of the last layer to scale the output
# we will rescale the parameters of the last layer to match the std of x

# init_gnn_std = gnn_reparam().std()
# # rescale the weights of the last layer by the ratio of the stds
# # gnn_reparam.gnn.layers[-1].weight.data *= init_sigma/init_gnn_std*1.

# gnn_reparam.gnn.layers[-1].weight.data *= x.std().item()/init_gnn_std*1.
print(f"std after rescaling {gnn_reparam().std().item():.3g}")

# instantiate the GNNMinimizerPytorch class
# gnn_minimizer = GNNMinimizerPytorch(
gnn_minimizer = GNNMinimizer(
    energy_lj, 1*initial_pos, gnn_reparam, optimizer_type='Adam', 
                            lr=1*LR, lr_gnn=2e-3,
                            # lr=2*LR, lr_gnn=4e-3,
                            clamp_grads=1e-2, log_step=20, log_pos_step=0, 
                            log_dir='../results/logs', log_name=f'GNN_Bond_LJ{num_cg_modes/n:.2f}',
                            patience=PATIENCE, min_delta=MIN_DELTA*1e-1, 
                            gnn_patience=PATIENCE, gnn_min_delta=MIN_DELTA*1e-1)
# Out:
# Initial std of x: 0.892
# std after rescaling 0.862
# Using Adam optimizer
# Log name: GNN_Bond_LJ0.33
# Logging to: ../results/logs/GNN_Bond_LJ0.33_n400_d3
# Using Adam optimizer

# %%
gnn_minimizer.energy_func(x), gnn_minimizer.energy_func(gnn_minimizer.get_x())
# Out:
# (tensor(1.9723, device='cuda:0'),
#  tensor(1.7545, device='cuda:0', grad_fn=<AddBackward0>))

# %%
exp_logger.run_experiment(gnn_minimizer, epochs=10, steps=5000, x0_std=initial_pos.std().item())
# Out:
# Running experiment GNN_Bond_LJ0.33_n400_d3
# 250 0.463, 6.71
# 500 0.462, 13.14
# Early stopping at step 2600
# Starting fine-graining
# Early stopping at step 4040
# 834 0.462, 19.63

# %%
for i in range(3):
    h= gnn_minimizer.train(20000)
# Out:
# Early stopping at step 9840
# Early stopping at step 4640
# Early stopping at step 1880

# %%
gnn_minimizer.plot_history(start=100)
gnn_minimizer.plot_history(start=gnn_minimizer.gnn_steps)
h = gnn_minimizer.history
plt.title(f'Energy vs time (min E: {min(h["energy"]):.3g}, t={np.sum(h["time"]):.2f} s)')
# Out:
# Text(0.5, 1.0, 'Energy vs time (min E: 0.462, t=31.25 s)')

# %%
r = 3e-1
# v = plot_graph_3D(V(cg_minimizer.get_x()), A, node_radius=r/2, edge_thickness=r, eps=1e-4, node_color='red', edge_color='red')
v = plot_line_3D(V(gnn_minimizer.get_x()), A, r = r, eps=1e-4, colormap='jet')

# Capture the current view as a PNG image
# v.png()
# Out:
# <div id="3dmolviewer_171502772854732"  style="position: relative; width: 600px; height: 600px;">
#         <p id="3dmolwarning_171502772854732" style="background-color:#ffcccc;color:black">You appear to be running in JupyterLab (or JavaScript failed to load for some other reason).  You need to install the 3dmol extension: <br>
#         <tt>jupyter labextension install jupyterlab_3dmol</tt></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdnjs.cloudflare.com/ajax/libs/3Dmol/2.0.4/3Dmol-min.js');
# }
#
# var viewer_171502772854732 = null;
# var warn = document.getElementById("3dmolwarning_171502772854732");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_171502772854732 = $3Dmol.createViewer(document.getElementById("3dmolviewer_171502772854732"),{backgroundColor:"white"});
# viewer_171502772854732.zoomTo();
# 	viewer_171502772854732.addCylinder({"start": {"x": -1.178841471672058, "y": 1.2453798055648804, "z": -7.191884994506836}, "end": {"x": -1.3149142265319824, "y": 0.36236757040023804, "z": -6.496739387512207}, "radius": 0.15, "color": "#000080", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -1.3149142265319824, "y": 0.36236757040023804, "z": -6.496739387512207}, "end": {"x": -1.7410352230072021, "y": 0.11594314128160477, "z": -5.476954460144043}, "radius": 0.15, "color": "#000080", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -1.7410352230072021, "y": 0.11594314128160477, "z": -5.476954460144043}, "end": {"x": -1.8540443181991577, "y": -0.20464549958705902, "z": -6.557059288024902}, "radius": 0.15, "color": "#000084", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -1.8540443181991577, "y": -0.20464549958705902, "z": -6.557059288024902}, "end": {"x": -2.809053421020508, "y": -0.21793493628501892, "z": -7.164455890655518}, "radius": 0.15, "color": "#000084", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -2.809053421020508, "y": -0.21793493628501892, "z": -7.164455890655518}, "end": {"x": -3.4829812049865723, "y": 0.24232158064842224, "z": -7.9498724937438965}, "radius": 0.15, "color": "#000089", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -3.4829812049865723, "y": 0.24232158064842224, "z": -7.9498724937438965}, "end": {"x": -4.109043598175049, "y": 1.04472815990448, "z": -8.444557189941406}, "radius": 0.15, "color": "#00008d", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -4.109043598175049, "y": 1.04472815990448, "z": -8.444557189941406}, "end": {"x": -3.907809257507324, "y": 2.147233724594116, "z": -8.609672546386719}, "radius": 0.15, "color": "#00008d", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -3.907809257507324, "y": 2.147233724594116, "z": -8.609672546386719}, "end": {"x": -3.362452268600464, "y": 2.938009738922119, "z": -8.013193130493164}, "radius": 0.15, "color": "#000092", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x": -3.362452268600464, "y": 2.938009738922119, "z": -8.013193130493164}, "end": {"x": -2.356245279312134, "y": 2.67435622215271, "z": -7.563055992126465}, "radius": 0.15, "color": "#000096", "opacity": 1});
# 	viewer_171502772854732.addCylinder({"start": {"x":